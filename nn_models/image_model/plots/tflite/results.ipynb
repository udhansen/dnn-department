# %%
import pandas as pd
import matplotlib.pyplot as plot

# %%
# Load all the profiling outputs from board

# CPU
df_cpu_def = pd.read_csv('/home/udhansen/nn_models/image_model/benchmark/board/tflite/benchmark_data_reg/run1000/cpu/default/Summary_by_node_type.csv', skiprows=1, index_col=0, skipinitialspace=True)
df_cpu_num1 = pd.read_csv('/home/udhansen/nn_models/image_model/benchmark/board/tflite/benchmark_data_reg/run1000/cpu/num1/Summary_by_node_type.csv', skiprows=1, index_col=0, skipinitialspace=True)
df_cpu_num2 = pd.read_csv('/home/udhansen/nn_models/image_model/benchmark/board/tflite/benchmark_data_reg/run1000/cpu/num2/Summary_by_node_type.csv', skiprows=1, index_col=0, skipinitialspace=True)
df_cpu_num4 = pd.read_csv('/home/udhansen/nn_models/image_model/benchmark/board/tflite/benchmark_data_reg/run1000/cpu/num4/Summary_by_node_type.csv', skiprows=1, index_col=0, skipinitialspace=True)

df_cpu_def = pd.DataFrame(df_cpu_def.sum()).T
df_cpu_num1 = pd.DataFrame(df_cpu_num1.sum()).T
df_cpu_num2 = pd.DataFrame(df_cpu_num2.sum()).T
df_cpu_num4 = pd.DataFrame(df_cpu_num4.sum()).T

# GPU
df_gpu_def = pd.read_csv('/home/udhansen/nn_models/image_model/benchmark/board/tflite/benchmark_data_reg/run1000/gpu/default/Summary_by_node_type.csv', skiprows=1, index_col=0, skipinitialspace=True)
df_gpu_num1 = pd.read_csv('/home/udhansen/nn_models/image_model/benchmark/board/tflite/benchmark_data_reg/run1000/gpu/num1/Summary_by_node_type.csv', skiprows=1, index_col=0, skipinitialspace=True)
df_gpu_num2 = pd.read_csv('/home/udhansen/nn_models/image_model/benchmark/board/tflite/benchmark_data_reg/run1000/gpu/num2/Summary_by_node_type.csv', skiprows=1, index_col=0, skipinitialspace=True)
df_gpu_num4 = pd.read_csv('/home/udhansen/nn_models/image_model/benchmark/board/tflite/benchmark_data_reg/run1000/gpu/num4/Summary_by_node_type.csv', skiprows=1, index_col=0, skipinitialspace=True)

# NPU
df_npu_def = pd.read_csv('/home/udhansen/nn_models/image_model/benchmark/board/tflite/benchmark_data_reg/run1000/npu/default/Summary_by_node_type.csv', skiprows=1, index_col=0, skipinitialspace=True)
df_npu_num1 = pd.read_csv('/home/udhansen/nn_models/image_model/benchmark/board/tflite/benchmark_data_reg/run1000/npu/num1/Summary_by_node_type.csv', skiprows=1, index_col=0, skipinitialspace=True)
df_npu_num2 = pd.read_csv('/home/udhansen/nn_models/image_model/benchmark/board/tflite/benchmark_data_reg/run1000/npu/num2/Summary_by_node_type.csv', skiprows=1, index_col=0, skipinitialspace=True)
df_npu_num4 = pd.read_csv('/home/udhansen/nn_models/image_model/benchmark/board/tflite/benchmark_data_reg/run1000/npu/num4/Summary_by_node_type.csv', skiprows=1, index_col=0, skipinitialspace=True)

# NNAPI
df_nnapi = pd.read_csv('/home/udhansen/nn_models/image_model/benchmark/board/tflite/benchmark_data_reg/run1000/nnapi/default/Summary_by_node_type.csv', skiprows=1, index_col=0, skipinitialspace=True)
df_nnapi_num1 = pd.read_csv('/home/udhansen/nn_models/image_model/benchmark/board/tflite/benchmark_data_reg/run1000/nnapi/num1/Summary_by_node_type.csv', skiprows=1, index_col=0, skipinitialspace=True)
df_nnapi_num2 = pd.read_csv('/home/udhansen/nn_models/image_model/benchmark/board/tflite/benchmark_data_reg/run1000/nnapi/num2/Summary_by_node_type.csv', skiprows=1, index_col=0, skipinitialspace=True)
df_nnapi_num4 = pd.read_csv('/home/udhansen/nn_models/image_model/benchmark/board/tflite/benchmark_data_reg/run1000/nnapi/num4/Summary_by_node_type.csv', skiprows=1, index_col=0, skipinitialspace=True)

# VX (GPU/NPU)
df_vx = pd.read_csv('/home/udhansen/nn_models/image_model/benchmark/board/tflite/benchmark_data_reg/run1000/vx/default/Summary_by_node_type.csv', skiprows=1, index_col=0, skipinitialspace=True)
df_vx_num1 = pd.read_csv('/home/udhansen/nn_models/image_model/benchmark/board/tflite/benchmark_data_reg/run1000/vx/num1/Summary_by_node_type.csv', skiprows=1, index_col=0, skipinitialspace=True)
df_vx_num2 = pd.read_csv('/home/udhansen/nn_models/image_model/benchmark/board/tflite/benchmark_data_reg/run1000/vx/num2/Summary_by_node_type.csv', skiprows=1, index_col=0, skipinitialspace=True)
df_vx_num4 = pd.read_csv('/home/udhansen/nn_models/image_model/benchmark/board/tflite/benchmark_data_reg/run1000/vx/num4/Summary_by_node_type.csv', skiprows=1, index_col=0, skipinitialspace=True)

# XNNPACK
df_xnnpack = pd.read_csv('/home/udhansen/nn_models/image_model/benchmark/board/tflite/benchmark_data_reg/run1000/xnnpack/default/Summary_by_node_type.csv', skiprows=1, index_col=0, skipinitialspace=True)
df_xnnpack_num1 = pd.read_csv('/home/udhansen/nn_models/image_model/benchmark/board/tflite/benchmark_data_reg/run1000/xnnpack/num1/Summary_by_node_type.csv', skiprows=1, index_col=0, skipinitialspace=True)
df_xnnpack_num2 = pd.read_csv('/home/udhansen/nn_models/image_model/benchmark/board/tflite/benchmark_data_reg/run1000/xnnpack/num2/Summary_by_node_type.csv', skiprows=1, index_col=0, skipinitialspace=True)
df_xnnpack_num4 = pd.read_csv('/home/udhansen/nn_models/image_model/benchmark/board/tflite/benchmark_data_reg/run1000/xnnpack/num4/Summary_by_node_type.csv', skiprows=1, index_col=0, skipinitialspace=True)

# %%
# Load all the profiling outputs from own computer 
df_cpu_pc = pd.read_csv('/home/udhansen/nn_models/image_model/benchmark/own_computer/tflite/benchmark_data_reg/run1/cpu/default/Summary_by_node_type.csv', skiprows=1, index_col=0, skipinitialspace=True)
df_cpu_num1_pc = pd.read_csv('/home/udhansen/nn_models/image_model/benchmark/own_computer/tflite/benchmark_data_reg/run1/cpu/num1/Summary_by_node_type.csv', skiprows=1, index_col=0, skipinitialspace=True)
df_cpu_num2_pc = pd.read_csv('/home/udhansen/nn_models/image_model/benchmark/own_computer/tflite/benchmark_data_reg/run1/cpu/num2/Summary_by_node_type.csv', skiprows=1, index_col=0, skipinitialspace=True)
df_cpu_num4_pc = pd.read_csv('/home/udhansen/nn_models/image_model/benchmark/own_computer/tflite/benchmark_data_reg/run1/cpu/num4/Summary_by_node_type.csv', skiprows=1, index_col=0, skipinitialspace=True)

df_cpu_pc = pd.DataFrame(df_cpu_pc.sum()).T
df_cpu_num1_pc = pd.DataFrame(df_cpu_num1_pc.sum()).T
df_cpu_num2_pc = pd.DataFrame(df_cpu_num1_pc.sum()).T
df_cpu_num4_pc = pd.DataFrame(df_cpu_num4_pc.sum()).T

# %%
df_avgms_data = pd.DataFrame({
    'def': [df_cpu_pc['avg_ms'][0], df_cpu_def['avg_ms'][0], df_gpu_def['avg_ms'][0], df_npu_def['avg_ms'][0], df_vx['avg_ms'][0], df_nnapi['avg_ms'][0], df_xnnpack['avg_ms'][0]],
    'num: 1': [df_cpu_num1_pc['avg_ms'][0], df_cpu_num1['avg_ms'][0], df_gpu_num1['avg_ms'][0], df_npu_num1['avg_ms'][0], df_vx_num1['avg_ms'][0], df_nnapi_num1['avg_ms'][0], df_xnnpack_num1['avg_ms'][0]],
    'num: 2': [df_cpu_num2_pc['avg_ms'][0], df_cpu_num2['avg_ms'][0], df_gpu_num2['avg_ms'][0], df_npu_num2['avg_ms'][0], df_vx_num2['avg_ms'][0], df_nnapi_num2['avg_ms'][0], df_xnnpack_num2['avg_ms'][0]],
    'num: 4': [df_cpu_num1_pc['avg_ms'][0], df_cpu_num4['avg_ms'][0], df_gpu_num4['avg_ms'][0], df_npu_num4['avg_ms'][0], df_vx_num4['avg_ms'][0], df_nnapi_num4['avg_ms'][0], df_xnnpack_num4['avg_ms'][0]]},
    index = ['cpu (PC)','cpu', 'gpu', 'npu', 'vx (gpu/npu)', 'nnapi', 'xnnpack']
)

# Converting from ms to us
#df_avgms_data = df_avgms_data * 1000

print(df_avgms_data)
# Out:
#                 def  num: 1  num: 2  num: 4
# cpu (PC)      0.007   0.007   0.007   0.007
# cpu           0.148   0.141   0.143   0.145
# gpu           0.583   0.823   0.539   0.591
# npu           0.276   0.276   0.276   0.276
# vx (gpu/npu)  0.276   0.277   0.277   0.276
# nnapi         0.344   0.347   0.346   0.348
# xnnpack       0.081   0.082   0.049   0.038

# %%
df_avgms_data.plot(kind="bar")
plot.xlabel('Hardware accelerators + delegates')
plot.xticks(rotation=45)
plot.ylabel('Time (us)')
# Out:
# Text(0, 0.5, 'Time (us)')
